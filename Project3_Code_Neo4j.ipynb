# %% [markdown]
# Create a graph database in Neo4j for the BART system

# %%
import neo4j

import csv

import math
import numpy as np
import pandas as pd

import psycopg2

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))

# %%
session = driver.session(database="neo4j")

# %%
def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)
    
    query = "match (node) delete node"
    session.run(query)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_number_nodes_relationships():
    "print the number of nodes and relationships"
   
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    print("-------------------------")
    print("  Nodes:", number_nodes)
    print("  Relationships:", number_relationships)
    print("-------------------------")

# %%
def my_neo4j_nodes_relationships():
    "print all the nodes and relationships"
   
    print("-------------------------")
    print("  Nodes:")
    print("-------------------------")
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    display(df)
    
    print("-------------------------")
    print("  Relationships:")
    print("-------------------------")
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    display(df)
    
    density = (2 * number_relationships) / (number_nodes * (number_nodes - 1))
    
    print("-------------------------")
    print("  Density:", f'{density:.1f}')
    print("-------------------------")

# %%
def my_neo4j_nodes():
    "print all the nodes and relationships"
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    new_df = pd.DataFrame(df)
    
    return(new_df)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_create_node(station_name):
    "create a node with label Station"
    
    query = """
    
    CREATE (:Station {name: $station_name})
    
    """
    
    session.run(query, station_name=station_name)

# %%
def my_neo4j_create_relationship_one_way(from_station, to_station, weight):
    "create a relationship one way between two stations with a weight"
    
    query = """
    
    MATCH (from:Station), 
          (to:Station)
    WHERE from.name = $from_station and to.name = $to_station
    CREATE (from)-[:LINK {weight: $weight}]->(to)
    
    """
    
    session.run(query, from_station=from_station, to_station=to_station, weight=weight)

# %%
def my_neo4j_create_relationship_two_way(from_station, to_station, weight):
    "create relationships two way between two stations with a weight"
    
    query = """
    
    MATCH (from:Station), 
          (to:Station)
    WHERE from.name = $from_station and to.name = $to_station
    CREATE (from)-[:LINK {weight: $weight}]->(to),
           (to)-[:LINK {weight: $weight}]->(from)
    
    """
    
    session.run(query, from_station=from_station, to_station=to_station, weight=weight)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
my_neo4j_wipe_out_database()

# %%
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 0
#   Relationships: 0
# -------------------------

# %%
connection.rollback()

query = """

select station
from stations
order by station

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    station = row[0]
    
    my_neo4j_create_node(station)

# %%
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 50
#   Relationships: 0
# -------------------------

# %%
connection.rollback()

query = """

select*
from travel_times

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    from_station = row[1]
    to_station = row[0]
    travel_time = int(row[2])
    
    my_neo4j_create_relationship_two_way(from_station, to_station, travel_time)

# %%
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 50
#   Relationships: 102
# -------------------------

# %%
connection.rollback()

query = """

select a.line, a.station as from_station, b.station as to_station, t.travel_time
from lines a
  join lines b
    on a.line = b.line and b.sequence = (a.sequence + 1)
  join travel_times t
    on (a.station = t.station_1 and b.station = t.station_2)
        or (a.station = t.station_2 and b.station = t.station_1)
order by line, from_station, to_station

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    line = row[0]
    from_station = row[1]
    to_station = row[2]
    travel_time = int(row[3])
    
    my_neo4j_create_relationship_two_way(from_station, to_station, travel_time)

# %%
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 50
#   Relationships: 318
# -------------------------

# %% [markdown]
# Centrality Algorithms

# %%
#Degree Centrality of BART stations
query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK')"
session.run(query)

# %%
query = """

CALL gds.degree.stream('ds_graph')
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).name AS name, score as degree
ORDER BY degree DESC, name

"""

degree_centrality_df = my_neo4j_run_query_pandas(query)

# %%
degree_centrality_df.head(50)
# Out:
#                     name  degree
# 0           West Oakland    11.0
# 1    16th Street Mission    10.0
# 2    24th Street Mission    10.0
# 3            Balboa Park    10.0
# 4           Civic Center    10.0
# 5               Coliseum    10.0
# 6            Embarcadero    10.0
# 7              Glen Park    10.0
# 8      Montgomery Street    10.0
# 9          Powell Street    10.0
# 10           12th Street     9.0
# 11              Bay Fair     9.0
# 12          Lake Merritt     9.0
# 13             MacArthur     9.0
# 14           19th Street     8.0
# 15             Daly City     8.0
# 16             Fruitvale     8.0
# 17           San Leandro     8.0
# 18             San Bruno     7.0
# 19                 Ashby     6.0
# 20                 Colma     6.0
# 21     Downtown Berkeley     6.0
# 22      El Cerrito Plaza     6.0
# 23  El Cerrito del Norte     6.0
# 24               Fremont     6.0
# 25               Hayward     6.0
# 26              Milpitas     6.0
# 27        North Berkeley     6.0
# 28         South Hayward     6.0
# 29   South San Francisco     6.0
# 30            Union City     6.0
# 31          Warm Springs     6.0
# 32         Castro Valley     4.0
# 33               Concord     4.0
# 34             Lafayette     4.0
# 35              Millbrae     4.0
# 36         North Concord     4.0
# 37                Orinda     4.0
# 38             Pittsburg     4.0
# 39      Pittsburg Center     4.0
# 40         Pleasant Hill     4.0
# 41             Rockridge     4.0
# 42                   SFO     4.0
# 43          Walnut Creek     4.0
# 44           West Dublin     4.0
# 45             Berryessa     3.0
# 46              Richmond     3.0
# 47               Antioch     2.0
# 48                Dublin     2.0
# 49                   OAK     2.0

# %%
#Closeness Centrality of BART stations

query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK')"
session.run(query)

# %%
query = """

CALL gds.beta.closeness.stream('ds_graph')
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).name AS name, score as closeness
ORDER BY score DESC

"""

closeness_centrality_df = my_neo4j_run_query_pandas(query)

# %%
closeness_centrality_df.head(50)
# Out:
#                     name  closeness
# 0            12th Street   0.147147
# 1           Lake Merritt   0.145833
# 2           West Oakland   0.145401
# 3            19th Street   0.141210
# 4              Fruitvale   0.137640
# 5            Embarcadero   0.136490
# 6              MacArthur   0.134986
# 7               Coliseum   0.129630
# 8      Montgomery Street   0.127937
# 9              Rockridge   0.124682
# 10                 Ashby   0.122195
# 11           San Leandro   0.121287
# 12         Powell Street   0.119804
# 13                Orinda   0.115294
# 14                   OAK   0.115023
# 15              Bay Fair   0.113426
# 16          Civic Center   0.112128
# 17     Downtown Berkeley   0.111111
# 18             Lafayette   0.106754
# 19   16th Street Mission   0.104925
# 20               Hayward   0.104701
# 21         Castro Valley   0.102941
# 22        North Berkeley   0.101449
# 23          Walnut Creek   0.098990
# 24   24th Street Mission   0.098196
# 25         South Hayward   0.096838
# 26           West Dublin   0.093870
# 27      El Cerrito Plaza   0.092979
# 28             Glen Park   0.091932
# 29         Pleasant Hill   0.091932
# 30            Union City   0.089744
# 31           Balboa Park   0.086116
# 32                Dublin   0.085965
# 33               Concord   0.085515
# 34  El Cerrito del Norte   0.085515
# 35               Fremont   0.083333
# 36             Daly City   0.080725
# 37         North Concord   0.079675
# 38              Richmond   0.078905
# 39          Warm Springs   0.077532
# 40                 Colma   0.075734
# 41             Pittsburg   0.074355
# 42              Milpitas   0.072271
# 43   South San Francisco   0.071118
# 44      Pittsburg Center   0.069504
# 45             Berryessa   0.067493
# 46             San Bruno   0.066849
# 47               Antioch   0.065073
# 48              Millbrae   0.062821
# 49                   SFO   0.062821

# %%
#Harmonic Centrality of BART stations
query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK')"
session.run(query)

# %%
query = """

CALL gds.alpha.closeness.harmonic.stream('ds_graph', {})
YIELD nodeId, centrality
RETURN gds.util.asNode(nodeId).name AS name, centrality as closeness
ORDER BY centrality DESC

"""

harmonic_centrality_df = my_neo4j_run_query_pandas(query)
harmonic_centrality_df.rename(columns={'closeness': 'harmonic'}, inplace=True)

# %%
harmonic_centrality_df.head(50)
# Out:
#                     name  harmonic
# 0            12th Street  0.233302
# 1           Lake Merritt  0.231867
# 2           West Oakland  0.228991
# 3              MacArthur  0.226052
# 4            19th Street  0.219525
# 5               Coliseum  0.216537
# 6              Fruitvale  0.214852
# 7               Bay Fair  0.209259
# 8            Embarcadero  0.204956
# 9            San Leandro  0.204085
# 10             Rockridge  0.201020
# 11                 Ashby  0.198599
# 12     Montgomery Street  0.192243
# 13                Orinda  0.187408
# 14               Hayward  0.186310
# 15         Powell Street  0.183524
# 16     Downtown Berkeley  0.182323
# 17         Castro Valley  0.179872
# 18             Lafayette  0.177701
# 19          Civic Center  0.176807
# 20         South Hayward  0.173498
# 21   16th Street Mission  0.171228
# 22          Walnut Creek  0.169799
# 23        North Berkeley  0.169367
# 24                   OAK  0.168257
# 25   24th Street Mission  0.166316
# 26            Union City  0.163598
# 27         Pleasant Hill  0.162728
# 28             Glen Park  0.161775
# 29           West Dublin  0.158443
# 30           Balboa Park  0.157391
# 31      El Cerrito Plaza  0.156995
# 32               Concord  0.155849
# 33               Fremont  0.154473
# 34             Daly City  0.153007
# 35         North Concord  0.148565
# 36                 Colma  0.148545
# 37          Warm Springs  0.144715
# 38   South San Francisco  0.144290
# 39             San Bruno  0.143603
# 40  El Cerrito del Norte  0.142626
# 41             Pittsburg  0.140030
# 42              Milpitas  0.132258
# 43                Dublin  0.130856
# 44      Pittsburg Center  0.128435
# 45              Millbrae  0.122641
# 46                   SFO  0.122641
# 47              Richmond  0.118996
# 48             Berryessa  0.110088
# 49               Antioch  0.106900

# %%
#Betweenness Centrality of BART stations

query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK')"
session.run(query)

# %%
query = """

CALL gds.betweenness.stream('ds_graph')
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).name AS name, score as betweenness
ORDER BY betweenness DESC

"""

betweenness_centrality_df = my_neo4j_run_query_pandas(query)

# %%
betweenness_centrality_df.head(50)
# Out:
#                     name  betweenness
# 0              MacArthur       1176.0
# 1            12th Street       1116.0
# 2            19th Street       1088.0
# 3           Lake Merritt       1020.0
# 4              Fruitvale        980.0
# 5           West Oakland        980.0
# 6               Coliseum        960.0
# 7            Embarcadero        936.0
# 8      Montgomery Street        888.0
# 9          Powell Street        836.0
# 10           San Leandro        836.0
# 11              Bay Fair        822.0
# 12          Civic Center        780.0
# 13   16th Street Mission        720.0
# 14             Rockridge        720.0
# 15   24th Street Mission        656.0
# 16                Orinda        656.0
# 17             Glen Park        588.0
# 18             Lafayette        588.0
# 19           Balboa Park        516.0
# 20               Hayward        516.0
# 21          Walnut Creek        516.0
# 22                 Ashby        440.0
# 23             Daly City        440.0
# 24         Pleasant Hill        440.0
# 25         South Hayward        440.0
# 26                 Colma        360.0
# 27               Concord        360.0
# 28     Downtown Berkeley        360.0
# 29            Union City        360.0
# 30               Fremont        276.0
# 31        North Berkeley        276.0
# 32         North Concord        276.0
# 33   South San Francisco        276.0
# 34             San Bruno        188.0
# 35         Castro Valley        188.0
# 36      El Cerrito Plaza        188.0
# 37             Pittsburg        188.0
# 38          Warm Springs        188.0
# 39           West Dublin         96.0
# 40  El Cerrito del Norte         96.0
# 41              Milpitas         96.0
# 42      Pittsburg Center         96.0
# 43               Antioch          0.0
# 44             Berryessa          0.0
# 45                Dublin          0.0
# 46              Millbrae          0.0
# 47                   OAK          0.0
# 48              Richmond          0.0
# 49                   SFO          0.0

# %%
#Louvain Modularity

query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = """

CALL gds.graph.project('ds_graph', 'Station', 'LINK')
"""

session.run(query)

# %%
query = """

CALL gds.louvain.stream('ds_graph')
YIELD nodeId, communityId, intermediateCommunityIds
RETURN gds.util.asNode(nodeId).name AS name, communityId as community, intermediateCommunityIds as intermediate_community
ORDER BY community, name ASC

"""

community_df = my_neo4j_run_query_pandas(query)
community_df
# Out:
#                     name  community intermediate_community
# 0    16th Street Mission         14                   None
# 1    24th Street Mission         14                   None
# 2            Balboa Park         14                   None
# 3              Daly City         14                   None
# 4              Glen Park         14                   None
# 5            12th Street         15                   None
# 6            19th Street         15                   None
# 7                  Ashby         15                   None
# 8      Downtown Berkeley         15                   None
# 9       El Cerrito Plaza         15                   None
# 10  El Cerrito del Norte         15                   None
# 11             MacArthur         15                   None
# 12        North Berkeley         15                   None
# 13              Richmond         15                   None
# 14             Berryessa         23                   None
# 15               Fremont         23                   None
# 16               Hayward         23                   None
# 17              Milpitas         23                   None
# 18         South Hayward         23                   None
# 19            Union City         23                   None
# 20          Warm Springs         23                   None
# 21              Bay Fair         25                   None
# 22         Castro Valley         25                   None
# 23              Coliseum         25                   None
# 24                Dublin         25                   None
# 25             Fruitvale         25                   None
# 26          Lake Merritt         25                   None
# 27                   OAK         25                   None
# 28           San Leandro         25                   None
# 29           West Dublin         25                   None
# 30          Civic Center         29                   None
# 31           Embarcadero         29                   None
# 32     Montgomery Street         29                   None
# 33         Powell Street         29                   None
# 34          West Oakland         29                   None
# 35               Antioch         31                   None
# 36               Concord         31                   None
# 37             Lafayette         31                   None
# 38         North Concord         31                   None
# 39                Orinda         31                   None
# 40             Pittsburg         31                   None
# 41      Pittsburg Center         31                   None
# 42         Pleasant Hill         31                   None
# 43             Rockridge         31                   None
# 44          Walnut Creek         31                   None
# 45                 Colma         42                   None
# 46              Millbrae         42                   None
# 47                   SFO         42                   None
# 48             San Bruno         42                   None
# 49   South San Francisco         42                   None

# %%
grouped_community_df = community_df.groupby('community')
for group_name, group_data in grouped_community_df:
    print(f"Community: {group_name}")
    print(group_data)
    print("----------------------------------")
# Out:
# Community: 14
#                   name  community intermediate_community
# 0  16th Street Mission         14                   None
# 1  24th Street Mission         14                   None
# 2          Balboa Park         14                   None
# 3            Daly City         14                   None
# 4            Glen Park         14                   None
# ----------------------------------
# Community: 15
#                     name  community intermediate_community
# 5            12th Street         15                   None
# 6            19th Street         15                   None
# 7                  Ashby         15                   None
# 8      Downtown Berkeley         15                   None
# 9       El Cerrito Plaza         15                   None
# 10  El Cerrito del Norte         15                   None
# 11             MacArthur         15                   None
# 12        North Berkeley         15                   None
# 13              Richmond         15                   None
# ----------------------------------
# Community: 23
#              name  community intermediate_community
# 14      Berryessa         23                   None
# 15        Fremont         23                   None
# 16        Hayward         23                   None
# 17       Milpitas         23                   None
# 18  South Hayward         23                   None
# 19     Union City         23                   None
# 20   Warm Springs         23                   None
# ----------------------------------
# Community: 25
#              name  community intermediate_community
# 21       Bay Fair         25                   None
# 22  Castro Valley         25                   None
# 23       Coliseum         25                   None
# 24         Dublin         25                   None
# 25      Fruitvale         25                   None
# 26   Lake Merritt         25                   None
# 27            OAK         25                   None
# 28    San Leandro         25                   None
# 29    West Dublin         25                   None
# ----------------------------------
# Community: 29
#                  name  community intermediate_community
# 30       Civic Center         29                   None
# 31        Embarcadero         29                   None
# 32  Montgomery Street         29                   None
# 33      Powell Street         29                   None
# 34       West Oakland         29                   None
# ----------------------------------
# Community: 31
#                 name  community intermediate_community
# 35           Antioch         31                   None
# 36           Concord         31                   None
# 37         Lafayette         31                   None
# 38     North Concord         31                   None
# 39            Orinda         31                   None
# 40         Pittsburg         31                   None
# 41  Pittsburg Center         31                   None
# 42     Pleasant Hill         31                   None
# 43         Rockridge         31                   None
# 44      Walnut Creek         31                   None
# ----------------------------------
# Community: 42
#                    name  community intermediate_community
# 45                Colma         42                   None
# 46             Millbrae         42                   None
# 47                  SFO         42                   None
# 48            San Bruno         42                   None
# 49  South San Francisco         42                   None
# ----------------------------------

# %%
# Merge degree_centrality_df and closeness_centrality_df
main_df = pd.merge(degree_centrality_df, closeness_centrality_df, on='name', how='outer')

# Merge harmonic_centrality_df and betweenness_centrality_df
main_df = pd.merge(main_df, harmonic_centrality_df, on='name', how='outer')

# Merge with betweenness_centrality_df
main_df = pd.merge(main_df, betweenness_centrality_df, on='name', how='outer')

# Merge with community_df
main_df = pd.merge(main_df, community_df, on='name', how='outer')

main_df
# Out:
#                     name  degree  closeness  harmonic  betweenness  community  \
# 0           West Oakland    11.0   0.145401  0.228991        980.0         29
# 1    16th Street Mission    10.0   0.104925  0.171228        720.0         14
# 2    24th Street Mission    10.0   0.098196  0.166316        656.0         14
# 3            Balboa Park    10.0   0.086116  0.157391        516.0         14
# 4           Civic Center    10.0   0.112128  0.176807        780.0         29
# 5               Coliseum    10.0   0.129630  0.216537        960.0         25
# 6            Embarcadero    10.0   0.136490  0.204956        936.0         29
# 7              Glen Park    10.0   0.091932  0.161775        588.0         14
# 8      Montgomery Street    10.0   0.127937  0.192243        888.0         29
# 9          Powell Street    10.0   0.119804  0.183524        836.0         29
# 10           12th Street     9.0   0.147147  0.233302       1116.0         15
# 11              Bay Fair     9.0   0.113426  0.209259        822.0         25
# 12          Lake Merritt     9.0   0.145833  0.231867       1020.0         25
# 13             MacArthur     9.0   0.134986  0.226052       1176.0         15
# 14           19th Street     8.0   0.141210  0.219525       1088.0         15
# 15             Daly City     8.0   0.080725  0.153007        440.0         14
# 16             Fruitvale     8.0   0.137640  0.214852        980.0         25
# 17           San Leandro     8.0   0.121287  0.204085        836.0         25
# 18             San Bruno     7.0   0.066849  0.143603        188.0         42
# 19                 Ashby     6.0   0.122195  0.198599        440.0         15
# 20                 Colma     6.0   0.075734  0.148545        360.0         42
# 21     Downtown Berkeley     6.0   0.111111  0.182323        360.0         15
# 22      El Cerrito Plaza     6.0   0.092979  0.156995        188.0         15
# 23  El Cerrito del Norte     6.0   0.085515  0.142626         96.0         15
# 24               Fremont     6.0   0.083333  0.154473        276.0         23
# 25               Hayward     6.0   0.104701  0.186310        516.0         23
# 26              Milpitas     6.0   0.072271  0.132258         96.0         23
# 27        North Berkeley     6.0   0.101449  0.169367        276.0         15
# 28         South Hayward     6.0   0.096838  0.173498        440.0         23
# 29   South San Francisco     6.0   0.071118  0.144290        276.0         42
# 30            Union City     6.0   0.089744  0.163598        360.0         23
# 31          Warm Springs     6.0   0.077532  0.144715        188.0         23
# 32         Castro Valley     4.0   0.102941  0.179872        188.0         25
# 33               Concord     4.0   0.085515  0.155849        360.0         31
# 34             Lafayette     4.0   0.106754  0.177701        588.0         31
# 35              Millbrae     4.0   0.062821  0.122641          0.0         42
# 36         North Concord     4.0   0.079675  0.148565        276.0         31
# 37                Orinda     4.0   0.115294  0.187408        656.0         31
# 38             Pittsburg     4.0   0.074355  0.140030        188.0         31
# 39      Pittsburg Center     4.0   0.069504  0.128435         96.0         31
# 40         Pleasant Hill     4.0   0.091932  0.162728        440.0         31
# 41             Rockridge     4.0   0.124682  0.201020        720.0         31
# 42                   SFO     4.0   0.062821  0.122641          0.0         42
# 43          Walnut Creek     4.0   0.098990  0.169799        516.0         31
# 44           West Dublin     4.0   0.093870  0.158443         96.0         25
# 45             Berryessa     3.0   0.067493  0.110088          0.0         23
# 46              Richmond     3.0   0.078905  0.118996          0.0         15
# 47               Antioch     2.0   0.065073  0.106900          0.0         31
# 48                Dublin     2.0   0.085965  0.130856          0.0         25
# 49                   OAK     2.0   0.115023  0.168257          0.0         25
#
#    intermediate_community
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# 5                    None
# 6                    None
# 7                    None
# 8                    None
# 9                    None
# 10                   None
# 11                   None
# 12                   None
# 13                   None
# 14                   None
# 15                   None
# 16                   None
# 17                   None
# 18                   None
# 19                   None
# 20                   None
# 21                   None
# 22                   None
# 23                   None
# 24                   None
# 25                   None
# 26                   None
# 27                   None
# 28                   None
# 29                   None
# 30                   None
# 31                   None
# 32                   None
# 33                   None
# 34                   None
# 35                   None
# 36                   None
# 37                   None
# 38                   None
# 39                   None
# 40                   None
# 41                   None
# 42                   None
# 43                   None
# 44                   None
# 45                   None
# 46                   None
# 47                   None
# 48                   None
# 49                   None

# %%
# Remove all station names with 0 results on centrality algo and community detection
main_clean_df = main_df[main_df['degree'] != 0]
# Drop column 'intermediate_commuinty'
main_clean_df = main_clean_df.drop('intermediate_community', axis=1)

main_clean_df
# Out:
#                     name  degree  closeness  harmonic  betweenness  community
# 0           West Oakland    11.0   0.145401  0.228991        980.0         29
# 1    16th Street Mission    10.0   0.104925  0.171228        720.0         14
# 2    24th Street Mission    10.0   0.098196  0.166316        656.0         14
# 3            Balboa Park    10.0   0.086116  0.157391        516.0         14
# 4           Civic Center    10.0   0.112128  0.176807        780.0         29
# 5               Coliseum    10.0   0.129630  0.216537        960.0         25
# 6            Embarcadero    10.0   0.136490  0.204956        936.0         29
# 7              Glen Park    10.0   0.091932  0.161775        588.0         14
# 8      Montgomery Street    10.0   0.127937  0.192243        888.0         29
# 9          Powell Street    10.0   0.119804  0.183524        836.0         29
# 10           12th Street     9.0   0.147147  0.233302       1116.0         15
# 11              Bay Fair     9.0   0.113426  0.209259        822.0         25
# 12          Lake Merritt     9.0   0.145833  0.231867       1020.0         25
# 13             MacArthur     9.0   0.134986  0.226052       1176.0         15
# 14           19th Street     8.0   0.141210  0.219525       1088.0         15
# 15             Daly City     8.0   0.080725  0.153007        440.0         14
# 16             Fruitvale     8.0   0.137640  0.214852        980.0         25
# 17           San Leandro     8.0   0.121287  0.204085        836.0         25
# 18             San Bruno     7.0   0.066849  0.143603        188.0         42
# 19                 Ashby     6.0   0.122195  0.198599        440.0         15
# 20                 Colma     6.0   0.075734  0.148545        360.0         42
# 21     Downtown Berkeley     6.0   0.111111  0.182323        360.0         15
# 22      El Cerrito Plaza     6.0   0.092979  0.156995        188.0         15
# 23  El Cerrito del Norte     6.0   0.085515  0.142626         96.0         15
# 24               Fremont     6.0   0.083333  0.154473        276.0         23
# 25               Hayward     6.0   0.104701  0.186310        516.0         23
# 26              Milpitas     6.0   0.072271  0.132258         96.0         23
# 27        North Berkeley     6.0   0.101449  0.169367        276.0         15
# 28         South Hayward     6.0   0.096838  0.173498        440.0         23
# 29   South San Francisco     6.0   0.071118  0.144290        276.0         42
# 30            Union City     6.0   0.089744  0.163598        360.0         23
# 31          Warm Springs     6.0   0.077532  0.144715        188.0         23
# 32         Castro Valley     4.0   0.102941  0.179872        188.0         25
# 33               Concord     4.0   0.085515  0.155849        360.0         31
# 34             Lafayette     4.0   0.106754  0.177701        588.0         31
# 35              Millbrae     4.0   0.062821  0.122641          0.0         42
# 36         North Concord     4.0   0.079675  0.148565        276.0         31
# 37                Orinda     4.0   0.115294  0.187408        656.0         31
# 38             Pittsburg     4.0   0.074355  0.140030        188.0         31
# 39      Pittsburg Center     4.0   0.069504  0.128435         96.0         31
# 40         Pleasant Hill     4.0   0.091932  0.162728        440.0         31
# 41             Rockridge     4.0   0.124682  0.201020        720.0         31
# 42                   SFO     4.0   0.062821  0.122641          0.0         42
# 43          Walnut Creek     4.0   0.098990  0.169799        516.0         31
# 44           West Dublin     4.0   0.093870  0.158443         96.0         25
# 45             Berryessa     3.0   0.067493  0.110088          0.0         23
# 46              Richmond     3.0   0.078905  0.118996          0.0         15
# 47               Antioch     2.0   0.065073  0.106900          0.0         31
# 48                Dublin     2.0   0.085965  0.130856          0.0         25
# 49                   OAK     2.0   0.115023  0.168257          0.0         25

# %% [markdown]
# Finding Total population within 1 mile of station

# %%
def my_calculate_box(point, miles):
    "Given a point and miles, calculate the box in form left, right, top, bottom"
    
    geod = Geodesic.WGS84

    kilometers = miles * 1.60934
    meters = kilometers * 1000

    g = geod.Direct(point[0], point[1], 270, meters)
    left = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 90, meters)
    right = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 0, meters)
    top = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 180, meters)
    bottom = (g['lat2'], g['lon2'])
    
    return(left, right, top, bottom)

# %%
import psycopg2
from geographiclib.geodesic import Geodesic

def my_station_get_zips(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    total_population = 0
    
    for row in rows:
        zip = row[0]
        population = row[1]
        total_population += population
        
    
    return total_population

# %%
# Create column for population_within_1mile of each station
main_clean_df['population_within_1mile'] = main_clean_df['name'].apply(my_station_get_zips, args=(1,))

main_clean_df
# Out:
#                     name  degree  closeness  harmonic  betweenness  community  \
# 0           West Oakland    11.0   0.145401  0.228991        980.0         29
# 1    16th Street Mission    10.0   0.104925  0.171228        720.0         14
# 2    24th Street Mission    10.0   0.098196  0.166316        656.0         14
# 3            Balboa Park    10.0   0.086116  0.157391        516.0         14
# 4           Civic Center    10.0   0.112128  0.176807        780.0         29
# 5               Coliseum    10.0   0.129630  0.216537        960.0         25
# 6            Embarcadero    10.0   0.136490  0.204956        936.0         29
# 7              Glen Park    10.0   0.091932  0.161775        588.0         14
# 8      Montgomery Street    10.0   0.127937  0.192243        888.0         29
# 9          Powell Street    10.0   0.119804  0.183524        836.0         29
# 10           12th Street     9.0   0.147147  0.233302       1116.0         15
# 11              Bay Fair     9.0   0.113426  0.209259        822.0         25
# 12          Lake Merritt     9.0   0.145833  0.231867       1020.0         25
# 13             MacArthur     9.0   0.134986  0.226052       1176.0         15
# 14           19th Street     8.0   0.141210  0.219525       1088.0         15
# 15             Daly City     8.0   0.080725  0.153007        440.0         14
# 16             Fruitvale     8.0   0.137640  0.214852        980.0         25
# 17           San Leandro     8.0   0.121287  0.204085        836.0         25
# 18             San Bruno     7.0   0.066849  0.143603        188.0         42
# 19                 Ashby     6.0   0.122195  0.198599        440.0         15
# 20                 Colma     6.0   0.075734  0.148545        360.0         42
# 21     Downtown Berkeley     6.0   0.111111  0.182323        360.0         15
# 22      El Cerrito Plaza     6.0   0.092979  0.156995        188.0         15
# 23  El Cerrito del Norte     6.0   0.085515  0.142626         96.0         15
# 24               Fremont     6.0   0.083333  0.154473        276.0         23
# 25               Hayward     6.0   0.104701  0.186310        516.0         23
# 26              Milpitas     6.0   0.072271  0.132258         96.0         23
# 27        North Berkeley     6.0   0.101449  0.169367        276.0         15
# 28         South Hayward     6.0   0.096838  0.173498        440.0         23
# 29   South San Francisco     6.0   0.071118  0.144290        276.0         42
# 30            Union City     6.0   0.089744  0.163598        360.0         23
# 31          Warm Springs     6.0   0.077532  0.144715        188.0         23
# 32         Castro Valley     4.0   0.102941  0.179872        188.0         25
# 33               Concord     4.0   0.085515  0.155849        360.0         31
# 34             Lafayette     4.0   0.106754  0.177701        588.0         31
# 35              Millbrae     4.0   0.062821  0.122641          0.0         42
# 36         North Concord     4.0   0.079675  0.148565        276.0         31
# 37                Orinda     4.0   0.115294  0.187408        656.0         31
# 38             Pittsburg     4.0   0.074355  0.140030        188.0         31
# 39      Pittsburg Center     4.0   0.069504  0.128435         96.0         31
# 40         Pleasant Hill     4.0   0.091932  0.162728        440.0         31
# 41             Rockridge     4.0   0.124682  0.201020        720.0         31
# 42                   SFO     4.0   0.062821  0.122641          0.0         42
# 43          Walnut Creek     4.0   0.098990  0.169799        516.0         31
# 44           West Dublin     4.0   0.093870  0.158443         96.0         25
# 45             Berryessa     3.0   0.067493  0.110088          0.0         23
# 46              Richmond     3.0   0.078905  0.118996          0.0         15
# 47               Antioch     2.0   0.065073  0.106900          0.0         31
# 48                Dublin     2.0   0.085965  0.130856          0.0         25
# 49                   OAK     2.0   0.115023  0.168257          0.0         25
#
#    population_within_1mile
# 0                    26254
# 1                    63489
# 2                   108915
# 3                   106589
# 4                    74898
# 5                        0
# 6                    54398
# 7                   115068
# 8                    85465
# 9                   140730
# 10                   16062
# 11                   41059
# 12                   16062
# 13                   22811
# 14                   16062
# 15                       0
# 16                   52299
# 17                   48088
# 18                   43124
# 19                   68219
# 20                   64887
# 21                   82930
# 22                   21040
# 23                       0
# 24                   73855
# 25                   66056
# 26                       0
# 27                   50769
# 28                   79235
# 29                       0
# 30                   74601
# 31                       0
# 32                       0
# 33                       0
# 34                   29639
# 35                   22710
# 36                   38568
# 37                   19341
# 38                       0
# 39                   96081
# 40                   22734
# 41                   39852
# 42                     135
# 43                   22734
# 44                       0
# 45                   28726
# 46                       0
# 47                       0
# 48                   54420
# 49                       0

# %% [markdown]
# Load Exist Number

# %%
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer
def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
def my_read_csv_file(file_name, limit):
    "read the csv file and print only the first limit rows"
    
    csv_file = open(file_name, "r")
    
    csv_data = csv.reader(csv_file)
    
    i = 0
    
    for row in csv_data:
        i += 1
        if i <= limit:
            print(row)
            
    print("\nPrinted ", min(limit, i), "lines of ", i, "total lines.")

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
connection.rollback()

query = """

drop table if exists station_entries_exits; 

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

create table station_entries_exits (
  station varchar(100),
  station_name varchar(100),
  entries numeric(12),
  exits numeric(12)
);

"""

cursor.execute(query)

connection.commit()

# %%
my_read_csv_file("station_entries_exits.csv", limit=10)
# Out:
# ['station', 'station_name', 'Entries', 'Exits']
# ['RM', 'Richmond', '58940', '55853']
# ['EN', 'El Cerrito del Norte', '87642', '90217']
# ['EP', 'El Cerrito Plaza', '49852', '49632']
# ['NB', 'North Berkeley', '46950', '44942']
# ['BK', 'Downtown Berkeley', '118302', '123180']
# ['AS', 'Ashby', '51830', '49312']
# ['MA', 'MacArthur', '94830', '91758']
# ['19', '19th Street', '113251', '107926']
# ['12', '12th Street', '119623', '115837']
#
# Printed  10 lines of  51 total lines.

# %%
connection.rollback()

query = """

copy station_entries_exits
from '/user/projects/project-3-nicole12hk/code/station_entries_exits.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

# %%
#Table shows number of exits for each station

rollback_before_flag = True
rollback_after_flag = True

query = """

select *
from station_entries_exits
order by exits desc

"""

station_entries_exits_df = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
station_entries_exits_df
# Out:
#    station          station_name  entries   exits
# 0       EM           Embarcadero   370182  420668
# 1       MT     Montgomery Street   295434  336738
# 2       PL         Powell Street   337468  304277
# 3       CC          Civic Center   251308  234454
# 4       16   16th Street Mission   150447  154355
# 5       24   24th Street Mission   139558  138430
# 6       BK     Downtown Berkeley   118302  123180
# 7       12           12th Street   119623  115837
# 8       19           19th Street   113251  107926
# 9       DC             Daly City    97685  100488
# 10      SO                   SFO   111823   97143
# 11      FV             Fruitvale    95590   94081
# 12      MA             MacArthur    94830   91758
# 13      EN  El Cerrito del Norte    87642   90217
# 14      BP           Balboa Park    96422   87415
# 15      OW          West Oakland    93142   84396
# 16      CL              Coliseum    80998   84167
# 17      GP             Glen Park    81193   78022
# 18      SL           San Leandro    76414   77476
# 19      ED                Dublin    77292   76364
# 20      LM          Lake Merritt    71296   74767
# 21      WC          Walnut Creek    63845   64033
# 22      BF              Bay Fair    62762   63233
# 23      RR             Rockridge    58658   59130
# 24      CN               Concord    59232   58652
# 25      MB              Millbrae    59485   57004
# 26      RM              Richmond    58940   55853
# 27      PH         Pleasant Hill    54380   53772
# 28      HY               Hayward    50911   50708
# 29      EP      El Cerrito Plaza    49852   49632
# 30      AS                 Ashby    51830   49312
# 31      FM               Fremont    48888   49297
# 32      NB        North Berkeley    46950   44942
# 33      UC            Union City    43594   43973
# 34      AN               Antioch    42109   42907
# 35      WP             Pittsburg    42324   42817
# 36      CM                 Colma    37259   36964
# 37      SB             San Bruno    34767   36323
# 38      LF             Lafayette    35684   35172
# 39      BE             Berryessa    33569   34344
# 40      SH         South Hayward    34806   33132
# 41      SS   South San Francisco    32478   32512
# 42      WD           West Dublin    30657   31954
# 43      WS          Warm Springs    32346   30327
# 44      ML              Milpitas    29439   29299
# 45      CV         Castro Valley    29002   28969
# 46      OR                Orinda    28986   28095
# 47      OA                   OAK    18667   17768
# 48      NC         North Concord    15056   14718
# 49      PC      Pittsburg Center    12839   12214

# %%
#Add entries and exits columns from station_entries_exits
merged_df = pd.merge(main_clean_df, station_entries_exits_df, left_on='name', right_on='station_name', how='inner')
merged_df.drop(columns=['station', 'station_name'], inplace=True)

merged_df
# Out:
#                     name  degree  closeness  harmonic  betweenness  community  \
# 0           West Oakland    11.0   0.145401  0.228991        980.0         29
# 1    16th Street Mission    10.0   0.104925  0.171228        720.0         14
# 2    24th Street Mission    10.0   0.098196  0.166316        656.0         14
# 3            Balboa Park    10.0   0.086116  0.157391        516.0         14
# 4           Civic Center    10.0   0.112128  0.176807        780.0         29
# 5               Coliseum    10.0   0.129630  0.216537        960.0         25
# 6            Embarcadero    10.0   0.136490  0.204956        936.0         29
# 7              Glen Park    10.0   0.091932  0.161775        588.0         14
# 8      Montgomery Street    10.0   0.127937  0.192243        888.0         29
# 9          Powell Street    10.0   0.119804  0.183524        836.0         29
# 10           12th Street     9.0   0.147147  0.233302       1116.0         15
# 11              Bay Fair     9.0   0.113426  0.209259        822.0         25
# 12          Lake Merritt     9.0   0.145833  0.231867       1020.0         25
# 13             MacArthur     9.0   0.134986  0.226052       1176.0         15
# 14           19th Street     8.0   0.141210  0.219525       1088.0         15
# 15             Daly City     8.0   0.080725  0.153007        440.0         14
# 16             Fruitvale     8.0   0.137640  0.214852        980.0         25
# 17           San Leandro     8.0   0.121287  0.204085        836.0         25
# 18             San Bruno     7.0   0.066849  0.143603        188.0         42
# 19                 Ashby     6.0   0.122195  0.198599        440.0         15
# 20                 Colma     6.0   0.075734  0.148545        360.0         42
# 21     Downtown Berkeley     6.0   0.111111  0.182323        360.0         15
# 22      El Cerrito Plaza     6.0   0.092979  0.156995        188.0         15
# 23  El Cerrito del Norte     6.0   0.085515  0.142626         96.0         15
# 24               Fremont     6.0   0.083333  0.154473        276.0         23
# 25               Hayward     6.0   0.104701  0.186310        516.0         23
# 26              Milpitas     6.0   0.072271  0.132258         96.0         23
# 27        North Berkeley     6.0   0.101449  0.169367        276.0         15
# 28         South Hayward     6.0   0.096838  0.173498        440.0         23
# 29   South San Francisco     6.0   0.071118  0.144290        276.0         42
# 30            Union City     6.0   0.089744  0.163598        360.0         23
# 31          Warm Springs     6.0   0.077532  0.144715        188.0         23
# 32         Castro Valley     4.0   0.102941  0.179872        188.0         25
# 33               Concord     4.0   0.085515  0.155849        360.0         31
# 34             Lafayette     4.0   0.106754  0.177701        588.0         31
# 35              Millbrae     4.0   0.062821  0.122641          0.0         42
# 36         North Concord     4.0   0.079675  0.148565        276.0         31
# 37                Orinda     4.0   0.115294  0.187408        656.0         31
# 38             Pittsburg     4.0   0.074355  0.140030        188.0         31
# 39      Pittsburg Center     4.0   0.069504  0.128435         96.0         31
# 40         Pleasant Hill     4.0   0.091932  0.162728        440.0         31
# 41             Rockridge     4.0   0.124682  0.201020        720.0         31
# 42                   SFO     4.0   0.062821  0.122641          0.0         42
# 43          Walnut Creek     4.0   0.098990  0.169799        516.0         31
# 44           West Dublin     4.0   0.093870  0.158443         96.0         25
# 45             Berryessa     3.0   0.067493  0.110088          0.0         23
# 46              Richmond     3.0   0.078905  0.118996          0.0         15
# 47               Antioch     2.0   0.065073  0.106900          0.0         31
# 48                Dublin     2.0   0.085965  0.130856          0.0         25
# 49                   OAK     2.0   0.115023  0.168257          0.0         25
#
#    population_within_1mile  entries   exits
# 0                    26254    93142   84396
# 1                    63489   150447  154355
# 2                   108915   139558  138430
# 3                   106589    96422   87415
# 4                    74898   251308  234454
# 5                        0    80998   84167
# 6                    54398   370182  420668
# 7                   115068    81193   78022
# 8                    85465   295434  336738
# 9                   140730   337468  304277
# 10                   16062   119623  115837
# 11                   41059    62762   63233
# 12                   16062    71296   74767
# 13                   22811    94830   91758
# 14                   16062   113251  107926
# 15                       0    97685  100488
# 16                   52299    95590   94081
# 17                   48088    76414   77476
# 18                   43124    34767   36323
# 19                   68219    51830   49312
# 20                   64887    37259   36964
# 21                   82930   118302  123180
# 22                   21040    49852   49632
# 23                       0    87642   90217
# 24                   73855    48888   49297
# 25                   66056    50911   50708
# 26                       0    29439   29299
# 27                   50769    46950   44942
# 28                   79235    34806   33132
# 29                       0    32478   32512
# 30                   74601    43594   43973
# 31                       0    32346   30327
# 32                       0    29002   28969
# 33                       0    59232   58652
# 34                   29639    35684   35172
# 35                   22710    59485   57004
# 36                   38568    15056   14718
# 37                   19341    28986   28095
# 38                       0    42324   42817
# 39                   96081    12839   12214
# 40                   22734    54380   53772
# 41                   39852    58658   59130
# 42                     135   111823   97143
# 43                   22734    63845   64033
# 44                       0    30657   31954
# 45                   28726    33569   34344
# 46                       0    58940   55853
# 47                       0    42109   42907
# 48                   54420    77292   76364
# 49                       0    18667   17768

# %%
#Add community column from community_df
final_df = pd.merge(merged_df, community_df, left_on='name', right_on='name', how='inner')
final_df.rename(columns = {'community_y':'community'}, inplace = True)
final_df.drop(columns=['community_x', 'intermediate_community'], inplace=True)
final_df

#final_sort1 = final_df.sort_values(by=['exits'],ascending=[False])
#final_sort1.head(30)
# Out:
#                     name  degree  closeness  harmonic  betweenness  \
# 0           West Oakland    11.0   0.145401  0.228991        980.0
# 1    16th Street Mission    10.0   0.104925  0.171228        720.0
# 2    24th Street Mission    10.0   0.098196  0.166316        656.0
# 3            Balboa Park    10.0   0.086116  0.157391        516.0
# 4           Civic Center    10.0   0.112128  0.176807        780.0
# 5               Coliseum    10.0   0.129630  0.216537        960.0
# 6            Embarcadero    10.0   0.136490  0.204956        936.0
# 7              Glen Park    10.0   0.091932  0.161775        588.0
# 8      Montgomery Street    10.0   0.127937  0.192243        888.0
# 9          Powell Street    10.0   0.119804  0.183524        836.0
# 10           12th Street     9.0   0.147147  0.233302       1116.0
# 11              Bay Fair     9.0   0.113426  0.209259        822.0
# 12          Lake Merritt     9.0   0.145833  0.231867       1020.0
# 13             MacArthur     9.0   0.134986  0.226052       1176.0
# 14           19th Street     8.0   0.141210  0.219525       1088.0
# 15             Daly City     8.0   0.080725  0.153007        440.0
# 16             Fruitvale     8.0   0.137640  0.214852        980.0
# 17           San Leandro     8.0   0.121287  0.204085        836.0
# 18             San Bruno     7.0   0.066849  0.143603        188.0
# 19                 Ashby     6.0   0.122195  0.198599        440.0
# 20                 Colma     6.0   0.075734  0.148545        360.0
# 21     Downtown Berkeley     6.0   0.111111  0.182323        360.0
# 22      El Cerrito Plaza     6.0   0.092979  0.156995        188.0
# 23  El Cerrito del Norte     6.0   0.085515  0.142626         96.0
# 24               Fremont     6.0   0.083333  0.154473        276.0
# 25               Hayward     6.0   0.104701  0.186310        516.0
# 26              Milpitas     6.0   0.072271  0.132258         96.0
# 27        North Berkeley     6.0   0.101449  0.169367        276.0
# 28         South Hayward     6.0   0.096838  0.173498        440.0
# 29   South San Francisco     6.0   0.071118  0.144290        276.0
# 30            Union City     6.0   0.089744  0.163598        360.0
# 31          Warm Springs     6.0   0.077532  0.144715        188.0
# 32         Castro Valley     4.0   0.102941  0.179872        188.0
# 33               Concord     4.0   0.085515  0.155849        360.0
# 34             Lafayette     4.0   0.106754  0.177701        588.0
# 35              Millbrae     4.0   0.062821  0.122641          0.0
# 36         North Concord     4.0   0.079675  0.148565        276.0
# 37                Orinda     4.0   0.115294  0.187408        656.0
# 38             Pittsburg     4.0   0.074355  0.140030        188.0
# 39      Pittsburg Center     4.0   0.069504  0.128435         96.0
# 40         Pleasant Hill     4.0   0.091932  0.162728        440.0
# 41             Rockridge     4.0   0.124682  0.201020        720.0
# 42                   SFO     4.0   0.062821  0.122641          0.0
# 43          Walnut Creek     4.0   0.098990  0.169799        516.0
# 44           West Dublin     4.0   0.093870  0.158443         96.0
# 45             Berryessa     3.0   0.067493  0.110088          0.0
# 46              Richmond     3.0   0.078905  0.118996          0.0
# 47               Antioch     2.0   0.065073  0.106900          0.0
# 48                Dublin     2.0   0.085965  0.130856          0.0
# 49                   OAK     2.0   0.115023  0.168257          0.0
#
#    population_within_1mile  entries   exits  community
# 0                    26254    93142   84396         29
# 1                    63489   150447  154355         14
# 2                   108915   139558  138430         14
# 3                   106589    96422   87415         14
# 4                    74898   251308  234454         29
# 5                        0    80998   84167         25
# 6                    54398   370182  420668         29
# 7                   115068    81193   78022         14
# 8                    85465   295434  336738         29
# 9                   140730   337468  304277         29
# 10                   16062   119623  115837         15
# 11                   41059    62762   63233         25
# 12                   16062    71296   74767         25
# 13                   22811    94830   91758         15
# 14                   16062   113251  107926         15
# 15                       0    97685  100488         14
# 16                   52299    95590   94081         25
# 17                   48088    76414   77476         25
# 18                   43124    34767   36323         42
# 19                   68219    51830   49312         15
# 20                   64887    37259   36964         42
# 21                   82930   118302  123180         15
# 22                   21040    49852   49632         15
# 23                       0    87642   90217         15
# 24                   73855    48888   49297         23
# 25                   66056    50911   50708         23
# 26                       0    29439   29299         23
# 27                   50769    46950   44942         15
# 28                   79235    34806   33132         23
# 29                       0    32478   32512         42
# 30                   74601    43594   43973         23
# 31                       0    32346   30327         23
# 32                       0    29002   28969         25
# 33                       0    59232   58652         31
# 34                   29639    35684   35172         31
# 35                   22710    59485   57004         42
# 36                   38568    15056   14718         31
# 37                   19341    28986   28095         31
# 38                       0    42324   42817         31
# 39                   96081    12839   12214         31
# 40                   22734    54380   53772         31
# 41                   39852    58658   59130         31
# 42                     135   111823   97143         42
# 43                   22734    63845   64033         31
# 44                       0    30657   31954         25
# 45                   28726    33569   34344         23
# 46                       0    58940   55853         15
# 47                       0    42109   42907         31
# 48                   54420    77292   76364         25
# 49                       0    18667   17768         25

# %% [markdown]
# Find Closest BART station for Existing Customers

# %%
#Customers table

rollback_before_flag = True
rollback_after_flag = True

query = """

select a.*, b.latitude, b.longitude
from customers a, zip_codes b
where a.zip = b.zip
and a.state = 'CA'

"""

customer_zip = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
customer_zip
# Out:
#       customer_id first_name    last_name                street          city  \
# 0               1       Robb      Weaving        5 Ramsey Place       Oakland
# 1               2      Robby     Belliard   6 Londonderry Plaza       Oakland
# 2               3    Sadella   Caudrelier   548 Mcguire Parkway       Oakland
# 3               4     Holmes    Shimmings      99 Kennedy Court       Oakland
# 4               5   Beverley       Gubbin      51 Mcbride Drive       Oakland
# ...           ...        ...          ...                   ...           ...
# 8133         8134   Wilmette      Raittie      331 Sommers Park  San Geronimo
# 8134         8135  Ammamaria       Newens          5 Esker Park  San Geronimo
# 8135         8136   Blakeley        Verry   1947 Thackeray Road  San Geronimo
# 8136         8137    Kikelia       Mendus  90777 Heath Crossing  San Geronimo
# 8137         8138      Nelly  Thurlbourne         8969 7th Park  San Geronimo
#
#      state    zip  closest_store_id  distance  latitude  longitude
# 0       CA  94609                 1         1   37.8343  -122.2643
# 1       CA  94609                 1         1   37.8343  -122.2643
# 2       CA  94609                 1         1   37.8343  -122.2643
# 3       CA  94609                 1         1   37.8343  -122.2643
# 4       CA  94609                 1         1   37.8343  -122.2643
# ...    ...    ...               ...       ...       ...        ...
# 8133    CA  94963                 1        25   38.0138  -122.6703
# 8134    CA  94963                 1        25   38.0138  -122.6703
# 8135    CA  94963                 1        25   38.0138  -122.6703
# 8136    CA  94963                 1        25   38.0138  -122.6703
# 8137    CA  94963                 1        25   38.0138  -122.6703
#
# [8138 rows x 11 columns]

# %%
# Creating a new column 'coordinates' with latitude and longitude in tuple format
customer_zip['coordinates'] = customer_zip.apply(lambda row: (row['latitude'], row['longitude']), axis=1)

# Display the updated DataFrame with the new 'coordinates' column
customer_zip
# Out:
#       customer_id first_name    last_name                street          city  \
# 0               1       Robb      Weaving        5 Ramsey Place       Oakland
# 1               2      Robby     Belliard   6 Londonderry Plaza       Oakland
# 2               3    Sadella   Caudrelier   548 Mcguire Parkway       Oakland
# 3               4     Holmes    Shimmings      99 Kennedy Court       Oakland
# 4               5   Beverley       Gubbin      51 Mcbride Drive       Oakland
# ...           ...        ...          ...                   ...           ...
# 8133         8134   Wilmette      Raittie      331 Sommers Park  San Geronimo
# 8134         8135  Ammamaria       Newens          5 Esker Park  San Geronimo
# 8135         8136   Blakeley        Verry   1947 Thackeray Road  San Geronimo
# 8136         8137    Kikelia       Mendus  90777 Heath Crossing  San Geronimo
# 8137         8138      Nelly  Thurlbourne         8969 7th Park  San Geronimo
#
#      state    zip  closest_store_id  distance  latitude  longitude  \
# 0       CA  94609                 1         1   37.8343  -122.2643
# 1       CA  94609                 1         1   37.8343  -122.2643
# 2       CA  94609                 1         1   37.8343  -122.2643
# 3       CA  94609                 1         1   37.8343  -122.2643
# 4       CA  94609                 1         1   37.8343  -122.2643
# ...    ...    ...               ...       ...       ...        ...
# 8133    CA  94963                 1        25   38.0138  -122.6703
# 8134    CA  94963                 1        25   38.0138  -122.6703
# 8135    CA  94963                 1        25   38.0138  -122.6703
# 8136    CA  94963                 1        25   38.0138  -122.6703
# 8137    CA  94963                 1        25   38.0138  -122.6703
#
#                coordinates
# 0     (37.8343, -122.2643)
# 1     (37.8343, -122.2643)
# 2     (37.8343, -122.2643)
# 3     (37.8343, -122.2643)
# 4     (37.8343, -122.2643)
# ...                    ...
# 8133  (38.0138, -122.6703)
# 8134  (38.0138, -122.6703)
# 8135  (38.0138, -122.6703)
# 8136  (38.0138, -122.6703)
# 8137  (38.0138, -122.6703)
#
# [8138 rows x 12 columns]

# %%
#Stations table

rollback_before_flag = True
rollback_after_flag = True

query = """

select *
from stations

"""

station_zip = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
station_zip
# Out:
#                  station   latitude   longitude  transfer_time
# 0            12th Street  37.803608 -122.272006            282
# 1    16th Street Mission  37.764847 -122.420042            287
# 2            19th Street  37.807869 -122.268980             67
# 3    24th Street Mission  37.752000 -122.418700            277
# 4                Antioch  37.996281 -121.783404              0
# 5                  Ashby  37.853068 -122.269957            299
# 6            Balboa Park  37.721667 -122.447500             48
# 7               Bay Fair  37.697000 -122.126500             63
# 8              Berryessa  37.368361 -121.874655            288
# 9          Castro Valley  37.690748 -122.075679              0
# 10          Civic Center  37.779861 -122.413498            325
# 11              Coliseum  37.753611 -122.196944             54
# 12                 Colma  37.684722 -122.466111            276
# 13               Concord  37.973745 -122.029127              0
# 14             Daly City  37.706224 -122.468934            285
# 15     Downtown Berkeley  37.869799 -122.268197            323
# 16                Dublin  37.701663 -121.899232              0
# 17      El Cerrito Plaza  37.902694 -122.298968            280
# 18  El Cerrito del Norte  37.925183 -122.316939            311
# 19           Embarcadero  37.793056 -122.397222            304
# 20               Fremont  37.557489 -121.976620            306
# 21             Fruitvale  37.774800 -122.224100            279
# 22             Glen Park  37.733118 -122.433808            314
# 23               Hayward  37.669700 -122.087000            284
# 24             Lafayette  37.893186 -122.124614              0
# 25          Lake Merritt  37.797773 -122.266588            309
# 26             MacArthur  37.828260 -122.267275             59
# 27              Millbrae  37.600300 -122.386700              0
# 28              Milpitas  37.410278 -121.891111            292
# 29     Montgomery Street  37.789355 -122.401942            313
# 30        North Berkeley  37.873915 -122.282552            289
# 31         North Concord  38.003273 -122.024599              0
# 32                   OAK  37.713200 -122.212200              0
# 33                Orinda  37.878427 -122.183740              0
# 34             Pittsburg  38.018869 -121.944208              0
# 35      Pittsburg Center  38.018227 -121.890178              0
# 36         Pleasant Hill  37.928399 -122.055992              0
# 37         Powell Street  37.784000 -122.408000            286
# 38              Richmond  37.936811 -122.353095            302
# 39             Rockridge  37.844452 -122.252083              0
# 40                   SFO  37.616400 -122.391000            291
# 41             San Bruno  37.638300 -122.416500            307
# 42           San Leandro  37.721764 -122.160684            298
# 43         South Hayward  37.634362 -122.057172            319
# 44   South San Francisco  37.664264 -122.444043            316
# 45            Union City  37.590746 -122.017282            293
# 46          Walnut Creek  37.905724 -122.067332              0
# 47          Warm Springs  37.503000 -121.940000            278
# 48           West Dublin  37.699726 -121.928273              0
# 49          West Oakland  37.804900 -122.295100            283

# %%
# Creating a new column 'coordinates' with latitude and longitude in tuple format
station_zip['coordinates'] = station_zip.apply(lambda row: (row['latitude'], row['longitude']), axis=1)

# Display the updated DataFrame with the new 'coordinates' column
station_zip
# Out:
#                  station   latitude   longitude  transfer_time  \
# 0            12th Street  37.803608 -122.272006            282
# 1    16th Street Mission  37.764847 -122.420042            287
# 2            19th Street  37.807869 -122.268980             67
# 3    24th Street Mission  37.752000 -122.418700            277
# 4                Antioch  37.996281 -121.783404              0
# 5                  Ashby  37.853068 -122.269957            299
# 6            Balboa Park  37.721667 -122.447500             48
# 7               Bay Fair  37.697000 -122.126500             63
# 8              Berryessa  37.368361 -121.874655            288
# 9          Castro Valley  37.690748 -122.075679              0
# 10          Civic Center  37.779861 -122.413498            325
# 11              Coliseum  37.753611 -122.196944             54
# 12                 Colma  37.684722 -122.466111            276
# 13               Concord  37.973745 -122.029127              0
# 14             Daly City  37.706224 -122.468934            285
# 15     Downtown Berkeley  37.869799 -122.268197            323
# 16                Dublin  37.701663 -121.899232              0
# 17      El Cerrito Plaza  37.902694 -122.298968            280
# 18  El Cerrito del Norte  37.925183 -122.316939            311
# 19           Embarcadero  37.793056 -122.397222            304
# 20               Fremont  37.557489 -121.976620            306
# 21             Fruitvale  37.774800 -122.224100            279
# 22             Glen Park  37.733118 -122.433808            314
# 23               Hayward  37.669700 -122.087000            284
# 24             Lafayette  37.893186 -122.124614              0
# 25          Lake Merritt  37.797773 -122.266588            309
# 26             MacArthur  37.828260 -122.267275             59
# 27              Millbrae  37.600300 -122.386700              0
# 28              Milpitas  37.410278 -121.891111            292
# 29     Montgomery Street  37.789355 -122.401942            313
# 30        North Berkeley  37.873915 -122.282552            289
# 31         North Concord  38.003273 -122.024599              0
# 32                   OAK  37.713200 -122.212200              0
# 33                Orinda  37.878427 -122.183740              0
# 34             Pittsburg  38.018869 -121.944208              0
# 35      Pittsburg Center  38.018227 -121.890178              0
# 36         Pleasant Hill  37.928399 -122.055992              0
# 37         Powell Street  37.784000 -122.408000            286
# 38              Richmond  37.936811 -122.353095            302
# 39             Rockridge  37.844452 -122.252083              0
# 40                   SFO  37.616400 -122.391000            291
# 41             San Bruno  37.638300 -122.416500            307
# 42           San Leandro  37.721764 -122.160684            298
# 43         South Hayward  37.634362 -122.057172            319
# 44   South San Francisco  37.664264 -122.444043            316
# 45            Union City  37.590746 -122.017282            293
# 46          Walnut Creek  37.905724 -122.067332              0
# 47          Warm Springs  37.503000 -121.940000            278
# 48           West Dublin  37.699726 -121.928273              0
# 49          West Oakland  37.804900 -122.295100            283
#
#                  coordinates
# 0   (37.803608, -122.272006)
# 1   (37.764847, -122.420042)
# 2    (37.807869, -122.26898)
# 3        (37.752, -122.4187)
# 4   (37.996281, -121.783404)
# 5   (37.853068, -122.269957)
# 6     (37.721667, -122.4475)
# 7        (37.697, -122.1265)
# 8   (37.368361, -121.874655)
# 9   (37.690748, -122.075679)
# 10  (37.779861, -122.413498)
# 11  (37.753611, -122.196944)
# 12  (37.684722, -122.466111)
# 13  (37.973745, -122.029127)
# 14  (37.706224, -122.468934)
# 15  (37.869799, -122.268197)
# 16  (37.701663, -121.899232)
# 17  (37.902694, -122.298968)
# 18  (37.925183, -122.316939)
# 19  (37.793056, -122.397222)
# 20   (37.557489, -121.97662)
# 21      (37.7748, -122.2241)
# 22  (37.733118, -122.433808)
# 23       (37.6697, -122.087)
# 24  (37.893186, -122.124614)
# 25  (37.797773, -122.266588)
# 26   (37.82826, -122.267275)
# 27      (37.6003, -122.3867)
# 28  (37.410278, -121.891111)
# 29  (37.789355, -122.401942)
# 30  (37.873915, -122.282552)
# 31  (38.003273, -122.024599)
# 32      (37.7132, -122.2122)
# 33   (37.878427, -122.18374)
# 34  (38.018869, -121.944208)
# 35  (38.018227, -121.890178)
# 36  (37.928399, -122.055992)
# 37        (37.784, -122.408)
# 38  (37.936811, -122.353095)
# 39  (37.844452, -122.252083)
# 40       (37.6164, -122.391)
# 41      (37.6383, -122.4165)
# 42  (37.721764, -122.160684)
# 43  (37.634362, -122.057172)
# 44  (37.664264, -122.444043)
# 45  (37.590746, -122.017282)
# 46  (37.905724, -122.067332)
# 47         (37.503, -121.94)
# 48  (37.699726, -121.928273)
# 49      (37.8049, -122.2951)

# %%
def my_calculate_distance(point_1, point_2):
    "Given two points in (latitude, longitude) format, calculate the distance between them in miles"
    
    geod = Geodesic.WGS84


    g = geod.Inverse(point_1[0], point_1[1], point_2[0], point_2[1])
    miles = g['s12'] / 1000 * 0.621371
    
    return miles

# %%
closest_stations = []
shortest_distances = []

# Loop through each customer's coordinates
for customer_coord in customer_zip['coordinates']:
    # Initialize variables for the closest station and shortest distance to this customer
    closest_station = None
    shortest_distance = float('inf')  # Initialize with a very large value

    # Loop through each train station's coordinates
    for station_coord in station_zip['coordinates']:
        # Calculate the distance between the customer and the station
        distance = my_calculate_distance(customer_coord, station_coord)
        
        # Update the closest station and shortest distance if the current station is closer
        if distance < shortest_distance:
            shortest_distance = distance
            closest_station = station_zip.loc[station_zip['coordinates'] == station_coord, 'station'].iloc[0]
    
    # Append the closest station and shortest distance to the respective lists
    closest_stations.append(closest_station)
    shortest_distances.append(shortest_distance)

# Add the results to the customer DataFrame
customer_zip['closest_station'] = closest_stations
customer_zip['shortest_distance'] = shortest_distances

# Display the updated customer DataFrame with the closest station and shortest distance
customer_zip.head(30)
# Out:
#     customer_id  first_name    last_name                      street     city  \
# 0             1        Robb      Weaving              5 Ramsey Place  Oakland
# 1             2       Robby     Belliard         6 Londonderry Plaza  Oakland
# 2             3     Sadella   Caudrelier         548 Mcguire Parkway  Oakland
# 3             4      Holmes    Shimmings            99 Kennedy Court  Oakland
# 4             5    Beverley       Gubbin            51 Mcbride Drive  Oakland
# 5             6       Pavia      Millery           463 Columbus Pass  Oakland
# 6             7    Engracia       Jeanon            24 Hanover Court  Oakland
# 7             8     Melinda        Stodd                568 Nova Way  Oakland
# 8             9      Dinnie         Leek               38 Golf Alley  Oakland
# 9            10     Caitrin   Filipowicz           61 Michigan Drive  Oakland
# 10           11     Sybille        Vipan              75841 2nd Hill  Oakland
# 11           12   Genevieve      Roughey            129 Katie Street  Oakland
# 12           13       Artie      Brandes            3744 Troy Circle  Oakland
# 13           14     Matilda       Keynes            73 Grayhawk Park  Oakland
# 14           15     Carmina      Wandrey         96472 Stephen Alley  Oakland
# 15           16      Tailor         Ades             50 Union Center  Oakland
# 16           17    Davidson    Stapleton                   5 2nd Way  Oakland
# 17           18       Julio    Vearncomb        600 Crownhardt Drive  Oakland
# 18           19       Alysa       Laight             8 Sunfield Hill  Oakland
# 19           20      Ragnar      Keeping               3 Iowa Avenue  Oakland
# 20           21        Kara      Faulder            2928 Aberg Drive  Oakland
# 21           22        Edie  Wholesworth  9393 Crescent Oaks Parkway  Oakland
# 22           23     Laurene        Righy          85651 Daystar Pass  Oakland
# 23           24       Elvyn    Rucklesse            38 Becker Center  Oakland
# 24           25    Theodore       Knaggs             25 Katie Center  Oakland
# 25           26      Putnam      Heaford           471 Knutson Place  Oakland
# 26           27     Richart   Scimonelli               8 Mallard Way  Oakland
# 27           28      Janith      Balbeck         45917 Red Cloud Way  Oakland
# 28           29  Wainwright     Armatage     4050 Mccormick Crossing  Oakland
# 29           30    Gherardo     Iacovone         489 Continental Way  Oakland
#
#    state    zip  closest_store_id  distance  latitude  longitude  \
# 0     CA  94609                 1         1   37.8343  -122.2643
# 1     CA  94609                 1         1   37.8343  -122.2643
# 2     CA  94609                 1         1   37.8343  -122.2643
# 3     CA  94609                 1         1   37.8343  -122.2643
# 4     CA  94609                 1         1   37.8343  -122.2643
# 5     CA  94609                 1         1   37.8343  -122.2643
# 6     CA  94609                 1         1   37.8343  -122.2643
# 7     CA  94609                 1         1   37.8343  -122.2643
# 8     CA  94609                 1         1   37.8343  -122.2643
# 9     CA  94609                 1         1   37.8343  -122.2643
# 10    CA  94609                 1         1   37.8343  -122.2643
# 11    CA  94609                 1         1   37.8343  -122.2643
# 12    CA  94609                 1         1   37.8343  -122.2643
# 13    CA  94609                 1         1   37.8343  -122.2643
# 14    CA  94609                 1         1   37.8343  -122.2643
# 15    CA  94609                 1         1   37.8343  -122.2643
# 16    CA  94609                 1         1   37.8343  -122.2643
# 17    CA  94609                 1         1   37.8343  -122.2643
# 18    CA  94609                 1         1   37.8343  -122.2643
# 19    CA  94609                 1         1   37.8343  -122.2643
# 20    CA  94609                 1         1   37.8343  -122.2643
# 21    CA  94609                 1         1   37.8343  -122.2643
# 22    CA  94609                 1         1   37.8343  -122.2643
# 23    CA  94609                 1         1   37.8343  -122.2643
# 24    CA  94609                 1         1   37.8343  -122.2643
# 25    CA  94609                 1         1   37.8343  -122.2643
# 26    CA  94609                 1         1   37.8343  -122.2643
# 27    CA  94609                 1         1   37.8343  -122.2643
# 28    CA  94609                 1         1   37.8343  -122.2643
# 29    CA  94609                 1         1   37.8343  -122.2643
#
#              coordinates closest_station  shortest_distance
# 0   (37.8343, -122.2643)       MacArthur           0.447226
# 1   (37.8343, -122.2643)       MacArthur           0.447226
# 2   (37.8343, -122.2643)       MacArthur           0.447226
# 3   (37.8343, -122.2643)       MacArthur           0.447226
# 4   (37.8343, -122.2643)       MacArthur           0.447226
# 5   (37.8343, -122.2643)       MacArthur           0.447226
# 6   (37.8343, -122.2643)       MacArthur           0.447226
# 7   (37.8343, -122.2643)       MacArthur           0.447226
# 8   (37.8343, -122.2643)       MacArthur           0.447226
# 9   (37.8343, -122.2643)       MacArthur           0.447226
# 10  (37.8343, -122.2643)       MacArthur           0.447226
# 11  (37.8343, -122.2643)       MacArthur           0.447226
# 12  (37.8343, -122.2643)       MacArthur           0.447226
# 13  (37.8343, -122.2643)       MacArthur           0.447226
# 14  (37.8343, -122.2643)       MacArthur           0.447226
# 15  (37.8343, -122.2643)       MacArthur           0.447226
# 16  (37.8343, -122.2643)       MacArthur           0.447226
# 17  (37.8343, -122.2643)       MacArthur           0.447226
# 18  (37.8343, -122.2643)       MacArthur           0.447226
# 19  (37.8343, -122.2643)       MacArthur           0.447226
# 20  (37.8343, -122.2643)       MacArthur           0.447226
# 21  (37.8343, -122.2643)       MacArthur           0.447226
# 22  (37.8343, -122.2643)       MacArthur           0.447226
# 23  (37.8343, -122.2643)       MacArthur           0.447226
# 24  (37.8343, -122.2643)       MacArthur           0.447226
# 25  (37.8343, -122.2643)       MacArthur           0.447226
# 26  (37.8343, -122.2643)       MacArthur           0.447226
# 27  (37.8343, -122.2643)       MacArthur           0.447226
# 28  (37.8343, -122.2643)       MacArthur           0.447226
# 29  (37.8343, -122.2643)       MacArthur           0.447226

# %%
closest_station_counts = customer_zip['closest_station'].value_counts().reset_index()
closest_station_counts.columns = ['closest_station', 'count']
closest_station_df = pd.DataFrame(closest_station_counts)
total_count = closest_station_counts['count'].sum()
closest_station_counts['percentage_of_count'] = closest_station_counts['count'] / total_count * 100

closest_station_df
# Out:
#          closest_station  count  percentage_of_count
# 0   El Cerrito del Norte    831            10.211354
# 1               Richmond    538             6.610961
# 2              Rockridge    494             6.070288
# 3           Civic Center    468             5.750799
# 4      Downtown Berkeley    463             5.689359
# 5              Fruitvale    440             5.406734
# 6       El Cerrito Plaza    409             5.025805
# 7              MacArthur    385             4.730892
# 8           Lake Merritt    375             4.608012
# 9            19th Street    337             4.141067
# 10          Walnut Creek    306             3.760138
# 11             Lafayette    265             3.256328
# 12        North Berkeley    246             3.022856
# 13          West Oakland    203             2.494470
# 14   16th Street Mission    198             2.433030
# 15                Orinda    194             2.383878
# 16              Coliseum    176             2.162694
# 17              Bay Fair    173             2.125829
# 18           Embarcadero    172             2.113541
# 19           Balboa Park    157             1.929221
# 20   24th Street Mission    145             1.781765
# 21         Powell Street    131             1.609732
# 22           San Leandro    130             1.597444
# 23                   OAK    128             1.572868
# 24             Glen Park    127             1.560580
# 25         Pleasant Hill     97             1.191939
# 26               Concord     95             1.167363
# 27              Millbrae     70             0.860162
# 28         North Concord     57             0.700418
# 29     Montgomery Street     55             0.675842
# 30                 Colma     45             0.552961
# 31   South San Francisco     41             0.503809
# 32             Daly City     37             0.454657
# 33         Castro Valley     33             0.405505
# 34         South Hayward     25             0.307201
# 35             San Bruno     19             0.233473
# 36                Dublin     18             0.221185
# 37            Union City     18             0.221185
# 38               Hayward     10             0.122880
# 39           West Dublin     10             0.122880
# 40      Pittsburg Center      8             0.098304
# 41               Fremont      8             0.098304
# 42                   SFO      1             0.012288

# %%
# Group closest station by community
merged_closest_station = closest_station_df.merge(final_df[['name', 'community']], left_on='closest_station', right_on='name', how='inner')
merged_closest_station
# Out:
#          closest_station  count  percentage_of_count                  name  \
# 0   El Cerrito del Norte    831            10.211354  El Cerrito del Norte
# 1               Richmond    538             6.610961              Richmond
# 2              Rockridge    494             6.070288             Rockridge
# 3           Civic Center    468             5.750799          Civic Center
# 4      Downtown Berkeley    463             5.689359     Downtown Berkeley
# 5              Fruitvale    440             5.406734             Fruitvale
# 6       El Cerrito Plaza    409             5.025805      El Cerrito Plaza
# 7              MacArthur    385             4.730892             MacArthur
# 8           Lake Merritt    375             4.608012          Lake Merritt
# 9            19th Street    337             4.141067           19th Street
# 10          Walnut Creek    306             3.760138          Walnut Creek
# 11             Lafayette    265             3.256328             Lafayette
# 12        North Berkeley    246             3.022856        North Berkeley
# 13          West Oakland    203             2.494470          West Oakland
# 14   16th Street Mission    198             2.433030   16th Street Mission
# 15                Orinda    194             2.383878                Orinda
# 16              Coliseum    176             2.162694              Coliseum
# 17              Bay Fair    173             2.125829              Bay Fair
# 18           Embarcadero    172             2.113541           Embarcadero
# 19           Balboa Park    157             1.929221           Balboa Park
# 20   24th Street Mission    145             1.781765   24th Street Mission
# 21         Powell Street    131             1.609732         Powell Street
# 22           San Leandro    130             1.597444           San Leandro
# 23                   OAK    128             1.572868                   OAK
# 24             Glen Park    127             1.560580             Glen Park
# 25         Pleasant Hill     97             1.191939         Pleasant Hill
# 26               Concord     95             1.167363               Concord
# 27              Millbrae     70             0.860162              Millbrae
# 28         North Concord     57             0.700418         North Concord
# 29     Montgomery Street     55             0.675842     Montgomery Street
# 30                 Colma     45             0.552961                 Colma
# 31   South San Francisco     41             0.503809   South San Francisco
# 32             Daly City     37             0.454657             Daly City
# 33         Castro Valley     33             0.405505         Castro Valley
# 34         South Hayward     25             0.307201         South Hayward
# 35             San Bruno     19             0.233473             San Bruno
# 36                Dublin     18             0.221185                Dublin
# 37            Union City     18             0.221185            Union City
# 38               Hayward     10             0.122880               Hayward
# 39           West Dublin     10             0.122880           West Dublin
# 40      Pittsburg Center      8             0.098304      Pittsburg Center
# 41               Fremont      8             0.098304               Fremont
# 42                   SFO      1             0.012288                   SFO
#
#     community
# 0          15
# 1          15
# 2          31
# 3          29
# 4          15
# 5          25
# 6          15
# 7          15
# 8          25
# 9          15
# 10         31
# 11         31
# 12         15
# 13         29
# 14         14
# 15         31
# 16         25
# 17         25
# 18         29
# 19         14
# 20         14
# 21         29
# 22         25
# 23         25
# 24         14
# 25         31
# 26         31
# 27         42
# 28         31
# 29         29
# 30         42
# 31         42
# 32         14
# 33         25
# 34         23
# 35         42
# 36         25
# 37         23
# 38         23
# 39         25
# 40         31
# 41         23
# 42         42

# %%
# Group closest station by community
merged_closest_station = closest_station_df.merge(final_df[['name', 'community']], left_on='closest_station', right_on='name', how='inner')
grouped_by_community = merged_closest_station.groupby('community')
community_counts = grouped_by_community.size().reset_index(name='customer_count')
print(community_counts)
# Out:
#    community  customer_count
# 0         14               5
# 1         15               7
# 2         23               4
# 3         25               9
# 4         29               5
# 5         31               8
# 6         42               5

# %%
final_groupby = merged_closest_station.groupby('community').apply(lambda x: x.sort_values(by='percentage_of_count', ascending=False))
display_final_groupby = final_groupby.reset_index(drop=True)
final_groupby_df = pd.DataFrame(display_final_groupby)
final_groupby_df
# Out:
#          closest_station  count  percentage_of_count                  name  \
# 0    16th Street Mission    198             2.433030   16th Street Mission
# 1            Balboa Park    157             1.929221           Balboa Park
# 2    24th Street Mission    145             1.781765   24th Street Mission
# 3              Glen Park    127             1.560580             Glen Park
# 4              Daly City     37             0.454657             Daly City
# 5   El Cerrito del Norte    831            10.211354  El Cerrito del Norte
# 6               Richmond    538             6.610961              Richmond
# 7      Downtown Berkeley    463             5.689359     Downtown Berkeley
# 8       El Cerrito Plaza    409             5.025805      El Cerrito Plaza
# 9              MacArthur    385             4.730892             MacArthur
# 10           19th Street    337             4.141067           19th Street
# 11        North Berkeley    246             3.022856        North Berkeley
# 12         South Hayward     25             0.307201         South Hayward
# 13            Union City     18             0.221185            Union City
# 14               Hayward     10             0.122880               Hayward
# 15               Fremont      8             0.098304               Fremont
# 16             Fruitvale    440             5.406734             Fruitvale
# 17          Lake Merritt    375             4.608012          Lake Merritt
# 18              Coliseum    176             2.162694              Coliseum
# 19              Bay Fair    173             2.125829              Bay Fair
# 20           San Leandro    130             1.597444           San Leandro
# 21                   OAK    128             1.572868                   OAK
# 22         Castro Valley     33             0.405505         Castro Valley
# 23                Dublin     18             0.221185                Dublin
# 24           West Dublin     10             0.122880           West Dublin
# 25          Civic Center    468             5.750799          Civic Center
# 26          West Oakland    203             2.494470          West Oakland
# 27           Embarcadero    172             2.113541           Embarcadero
# 28         Powell Street    131             1.609732         Powell Street
# 29     Montgomery Street     55             0.675842     Montgomery Street
# 30             Rockridge    494             6.070288             Rockridge
# 31          Walnut Creek    306             3.760138          Walnut Creek
# 32             Lafayette    265             3.256328             Lafayette
# 33                Orinda    194             2.383878                Orinda
# 34         Pleasant Hill     97             1.191939         Pleasant Hill
# 35               Concord     95             1.167363               Concord
# 36         North Concord     57             0.700418         North Concord
# 37      Pittsburg Center      8             0.098304      Pittsburg Center
# 38              Millbrae     70             0.860162              Millbrae
# 39                 Colma     45             0.552961                 Colma
# 40   South San Francisco     41             0.503809   South San Francisco
# 41             San Bruno     19             0.233473             San Bruno
# 42                   SFO      1             0.012288                   SFO
#
#     community
# 0          14
# 1          14
# 2          14
# 3          14
# 4          14
# 5          15
# 6          15
# 7          15
# 8          15
# 9          15
# 10         15
# 11         15
# 12         23
# 13         23
# 14         23
# 15         23
# 16         25
# 17         25
# 18         25
# 19         25
# 20         25
# 21         25
# 22         25
# 23         25
# 24         25
# 25         29
# 26         29
# 27         29
# 28         29
# 29         29
# 30         31
# 31         31
# 32         31
# 33         31
# 34         31
# 35         31
# 36         31
# 37         31
# 38         42
# 39         42
# 40         42
# 41         42
# 42         42

# %% [markdown]
# Sorting Centrality Algorithms results

# %%
# Analysis on harmonic centrality
# Stations with harmonic degree centrality and exits
harmonic_final_df = final_df[['name','harmonic', 'population_within_1mile', 'entries','exits','community']]
harmonic_sort1 = harmonic_final_df.sort_values(by=['harmonic','exits'],ascending=[False, False])
harmonic_sort1.head(30)
# Out:
#                    name  harmonic population_within_1mile  entries   exits  \
# 10          12th Street  0.233302                   16062   119623  115837
# 12         Lake Merritt  0.231867                   16062    71296   74767
# 0          West Oakland  0.228991                   26254    93142   84396
# 13            MacArthur  0.226052                   22811    94830   91758
# 14          19th Street  0.219525                   16062   113251  107926
# 5              Coliseum  0.216537                       0    80998   84167
# 16            Fruitvale  0.214852                   52299    95590   94081
# 11             Bay Fair  0.209259                   41059    62762   63233
# 6           Embarcadero  0.204956                   54398   370182  420668
# 17          San Leandro  0.204085                   48088    76414   77476
# 41            Rockridge  0.201020                   39852    58658   59130
# 19                Ashby  0.198599                   68219    51830   49312
# 8     Montgomery Street  0.192243                   85465   295434  336738
# 37               Orinda  0.187408                   19341    28986   28095
# 25              Hayward  0.186310                   66056    50911   50708
# 9         Powell Street  0.183524                  140730   337468  304277
# 21    Downtown Berkeley  0.182323                   82930   118302  123180
# 32        Castro Valley  0.179872                       0    29002   28969
# 34            Lafayette  0.177701                   29639    35684   35172
# 4          Civic Center  0.176807                   74898   251308  234454
# 28        South Hayward  0.173498                   79235    34806   33132
# 1   16th Street Mission  0.171228                   63489   150447  154355
# 43         Walnut Creek  0.169799                   22734    63845   64033
# 27       North Berkeley  0.169367                   50769    46950   44942
# 49                  OAK  0.168257                       0    18667   17768
# 2   24th Street Mission  0.166316                  108915   139558  138430
# 30           Union City  0.163598                   74601    43594   43973
# 40        Pleasant Hill  0.162728                   22734    54380   53772
# 7             Glen Park  0.161775                  115068    81193   78022
# 44          West Dublin  0.158443                       0    30657   31954
#
#     community
# 10         15
# 12         25
# 0          29
# 13         15
# 14         15
# 5          25
# 16         25
# 11         25
# 6          29
# 17         25
# 41         31
# 19         15
# 8          29
# 37         31
# 25         23
# 9          29
# 21         15
# 32         25
# 34         31
# 4          29
# 28         23
# 1          14
# 43         31
# 27         15
# 49         25
# 2          14
# 30         23
# 40         31
# 7          14
# 44         25

# %%
# Stations with harmonic harmonic centrality and population
harmonic_final_df = final_df[['name','harmonic', 'population_within_1mile', 'entries','exits','community']]
harmonic_sort2 = harmonic_final_df.sort_values(by=['harmonic','population_within_1mile'],ascending=[False, False])
harmonic_sort2.head(30)
# Out:
#                    name  harmonic population_within_1mile  entries   exits  \
# 10          12th Street  0.233302                   16062   119623  115837
# 12         Lake Merritt  0.231867                   16062    71296   74767
# 0          West Oakland  0.228991                   26254    93142   84396
# 13            MacArthur  0.226052                   22811    94830   91758
# 14          19th Street  0.219525                   16062   113251  107926
# 5              Coliseum  0.216537                       0    80998   84167
# 16            Fruitvale  0.214852                   52299    95590   94081
# 11             Bay Fair  0.209259                   41059    62762   63233
# 6           Embarcadero  0.204956                   54398   370182  420668
# 17          San Leandro  0.204085                   48088    76414   77476
# 41            Rockridge  0.201020                   39852    58658   59130
# 19                Ashby  0.198599                   68219    51830   49312
# 8     Montgomery Street  0.192243                   85465   295434  336738
# 37               Orinda  0.187408                   19341    28986   28095
# 25              Hayward  0.186310                   66056    50911   50708
# 9         Powell Street  0.183524                  140730   337468  304277
# 21    Downtown Berkeley  0.182323                   82930   118302  123180
# 32        Castro Valley  0.179872                       0    29002   28969
# 34            Lafayette  0.177701                   29639    35684   35172
# 4          Civic Center  0.176807                   74898   251308  234454
# 28        South Hayward  0.173498                   79235    34806   33132
# 1   16th Street Mission  0.171228                   63489   150447  154355
# 43         Walnut Creek  0.169799                   22734    63845   64033
# 27       North Berkeley  0.169367                   50769    46950   44942
# 49                  OAK  0.168257                       0    18667   17768
# 2   24th Street Mission  0.166316                  108915   139558  138430
# 30           Union City  0.163598                   74601    43594   43973
# 40        Pleasant Hill  0.162728                   22734    54380   53772
# 7             Glen Park  0.161775                  115068    81193   78022
# 44          West Dublin  0.158443                       0    30657   31954
#
#     community
# 10         15
# 12         25
# 0          29
# 13         15
# 14         15
# 5          25
# 16         25
# 11         25
# 6          29
# 17         25
# 41         31
# 19         15
# 8          29
# 37         31
# 25         23
# 9          29
# 21         15
# 32         25
# 34         31
# 4          29
# 28         23
# 1          14
# 43         31
# 27         15
# 49         25
# 2          14
# 30         23
# 40         31
# 7          14
# 44         25

# %%
# Analysis on betweenness centrality
# Stations with betweenness betweenness centrality and exits
betweenness_final_df = final_df[['name','betweenness', 'population_within_1mile', 'entries','exits','community']]
betweenness_sort1 = betweenness_final_df.sort_values(by=['betweenness','exits'],ascending=[False, False])
betweenness_sort1.head(30)
# Out:
#                    name  betweenness population_within_1mile  entries   exits  \
# 13            MacArthur       1176.0                   22811    94830   91758
# 10          12th Street       1116.0                   16062   119623  115837
# 14          19th Street       1088.0                   16062   113251  107926
# 12         Lake Merritt       1020.0                   16062    71296   74767
# 16            Fruitvale        980.0                   52299    95590   94081
# 0          West Oakland        980.0                   26254    93142   84396
# 5              Coliseum        960.0                       0    80998   84167
# 6           Embarcadero        936.0                   54398   370182  420668
# 8     Montgomery Street        888.0                   85465   295434  336738
# 9         Powell Street        836.0                  140730   337468  304277
# 17          San Leandro        836.0                   48088    76414   77476
# 11             Bay Fair        822.0                   41059    62762   63233
# 4          Civic Center        780.0                   74898   251308  234454
# 1   16th Street Mission        720.0                   63489   150447  154355
# 41            Rockridge        720.0                   39852    58658   59130
# 2   24th Street Mission        656.0                  108915   139558  138430
# 37               Orinda        656.0                   19341    28986   28095
# 7             Glen Park        588.0                  115068    81193   78022
# 34            Lafayette        588.0                   29639    35684   35172
# 3           Balboa Park        516.0                  106589    96422   87415
# 43         Walnut Creek        516.0                   22734    63845   64033
# 25              Hayward        516.0                   66056    50911   50708
# 15            Daly City        440.0                       0    97685  100488
# 40        Pleasant Hill        440.0                   22734    54380   53772
# 19                Ashby        440.0                   68219    51830   49312
# 28        South Hayward        440.0                   79235    34806   33132
# 21    Downtown Berkeley        360.0                   82930   118302  123180
# 33              Concord        360.0                       0    59232   58652
# 30           Union City        360.0                   74601    43594   43973
# 20                Colma        360.0                   64887    37259   36964
#
#     community
# 13         15
# 10         15
# 14         15
# 12         25
# 16         25
# 0          29
# 5          25
# 6          29
# 8          29
# 9          29
# 17         25
# 11         25
# 4          29
# 1          14
# 41         31
# 2          14
# 37         31
# 7          14
# 34         31
# 3          14
# 43         31
# 25         23
# 15         14
# 40         31
# 19         15
# 28         23
# 21         15
# 33         31
# 30         23
# 20         42

# %%
# Stations with betweenness betweenness centrality and population
betweenness_final_df = final_df[['name','betweenness', 'population_within_1mile', 'entries','exits','community']]
betweenness_sort2 = betweenness_final_df.sort_values(by=['betweenness','population_within_1mile'],ascending=[False, False])
betweenness_sort2.head(30)
# Out:
#                    name  betweenness population_within_1mile  entries   exits  \
# 13            MacArthur       1176.0                   22811    94830   91758
# 10          12th Street       1116.0                   16062   119623  115837
# 14          19th Street       1088.0                   16062   113251  107926
# 12         Lake Merritt       1020.0                   16062    71296   74767
# 16            Fruitvale        980.0                   52299    95590   94081
# 0          West Oakland        980.0                   26254    93142   84396
# 5              Coliseum        960.0                       0    80998   84167
# 6           Embarcadero        936.0                   54398   370182  420668
# 8     Montgomery Street        888.0                   85465   295434  336738
# 9         Powell Street        836.0                  140730   337468  304277
# 17          San Leandro        836.0                   48088    76414   77476
# 11             Bay Fair        822.0                   41059    62762   63233
# 4          Civic Center        780.0                   74898   251308  234454
# 1   16th Street Mission        720.0                   63489   150447  154355
# 41            Rockridge        720.0                   39852    58658   59130
# 2   24th Street Mission        656.0                  108915   139558  138430
# 37               Orinda        656.0                   19341    28986   28095
# 7             Glen Park        588.0                  115068    81193   78022
# 34            Lafayette        588.0                   29639    35684   35172
# 3           Balboa Park        516.0                  106589    96422   87415
# 25              Hayward        516.0                   66056    50911   50708
# 43         Walnut Creek        516.0                   22734    63845   64033
# 28        South Hayward        440.0                   79235    34806   33132
# 19                Ashby        440.0                   68219    51830   49312
# 40        Pleasant Hill        440.0                   22734    54380   53772
# 15            Daly City        440.0                       0    97685  100488
# 21    Downtown Berkeley        360.0                   82930   118302  123180
# 30           Union City        360.0                   74601    43594   43973
# 20                Colma        360.0                   64887    37259   36964
# 33              Concord        360.0                       0    59232   58652
#
#     community
# 13         15
# 10         15
# 14         15
# 12         25
# 16         25
# 0          29
# 5          25
# 6          29
# 8          29
# 9          29
# 17         25
# 11         25
# 4          29
# 1          14
# 41         31
# 2          14
# 37         31
# 7          14
# 34         31
# 3          14
# 25         23
# 43         31
# 28         23
# 19         15
# 40         31
# 15         14
# 21         15
# 30         23
# 20         42
# 33         31
